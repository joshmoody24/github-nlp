# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

data = pd.read_csv(f'./quarterly_repo_metrics.csv')

# Extract the relevant columns (numeric ones) for correlation analysis
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
# drop anything with "Unnamed" in the name
numeric_columns = [col for col in numeric_columns if 'Unnamed' not in col]

# Shift the numeric columns to get the next quarter's data for each row
for col in numeric_columns:
    data[f'next_{col}'] = data.groupby('Unnamed: 1')[col].shift(-1)

# sort columns to make it easier to read
# first show columns that end with '_count', then '_ratio', then everything else alphabetically
numeric_columns = sorted(numeric_columns, key=lambda col: (col.endswith('_count'), col.endswith('_ratio'), col.endswith('_growth_rate'), col))

# Drop rows where the next quarter's data is NaN (end of the sequence for each repo)
extended_data = data.dropna(subset=[f'next_{col}' for col in numeric_columns], how='all')
data = extended_data.fillna(0)

# format is YYYYQ1, but let's just parse only the year
data['year'] = pd.to_datetime(data['Unnamed: 0'].str[:4] + '-01-01') # quarterlly
data = data[(data['year'] >= '2013-01-01') & (data['year'] <= '2023-01-01')]

# data['year'] = pd.to_datetime(data['Unnamed: 0'], format="%Y") # yearly
# data = data[(data['year'] >= '2013-01-01') & (data['year'] <= '2023-01-01')]

# take log of all growth rate columns
for col in data.columns:
    if col.endswith('_growth_rate'):
        data[col] = np.log1p(data[col])

# unused repo size filtering
# SMALL_REPOS = [
#     ('joshmoody24', 'sitcom-simulator'),
#     ('nodejs', 'nodejs.org'),
#     ('spacejam', 'sled'),
#     ('Auto1111SDK', 'Auto1111SDK'),
#     ('stitionai', 'devika'),
#     ('zzzprojects', 'System.Linq.Dynamic.Core'),
#     ('elnormous', 'HTTPRequest'),
# ]

# LARGE_REPOS = [
#     ('pallets', 'flask'),
#     ('facebook', 'react'),
#     ('hotwired', 'turbo'),
#     ('rails', 'rails'),
#     ('vuejs', 'core'), #
#     ('Zulko', 'moviepy'),
#     ('withastro', 'astro'),
#     ('bigskysoftware', 'htmx'),
#     ('phoenixframework', 'phoenix'),
#     ('ethereum', 'go-ethereum'),
#     ('twbs', 'bootstrap'),
#     ('django', 'django'),
# ]

# # filter data to only contain small repos
# filtered_data = pd.DataFrame()
# for owner, repo in SMALL_REPOS:
#     filtered_data = pd.concat([filtered_data, data[data['Unnamed: 1'] == f'{owner}/{repo}']])
# data = filtered_data
        
print("Total rows", len(data))

for dependent_variable in ['next_' + col for col in numeric_columns] + ['star_growth_rate']:
    print(f"Model for {dependent_variable}")
    X = data.drop([dependent_variable, 'Unnamed: 0', 'Unnamed: 1', 'code_comment_count_growth_rate', 'issue_comment_count_growth_rate'], axis=1) # remove the raw sums
    # dummy code repo (Unnamed: 1) (not useful because we're interested in generalities that apply to all repos)
    # X = pd.get_dummies(X, columns=['Unnamed: 1']).astype(float)
    X = X.drop([col for col in X.columns if 'next_' in col or 'star' in col], axis=1)
    X = X.select_dtypes(include=['float64', 'int64'])

    # normalize the data
    X = (X - X.mean()) / X.std()
    
    y = data[dependent_variable]
    X = sm.add_constant(X)
    
    model = sm.OLS(y, X).fit()

    # p-hacking (unused)
    # while True:
    #     model = sm.OLS(y, X).fit()
    #     p_values = model.pvalues.drop('const', errors='ignore')  # ignore errors in case 'const' is not present
    #     max_p_value = p_values.max()

    #     if max_p_value < 0.5 or len(X.columns) == 1: # get rid of the super lame features
    #         break

    #     # Drop the feature with the highest p-value
    #     feature_to_drop = p_values.idxmax()
    #     X = X.drop(columns=feature_to_drop)
    
    print(f"R-squared: {round(model.rsquared, 4)}")
    print(f"Adjusted R-squared: {round(model.rsquared_adj, 4)}")
    print("Significant Coefficients:")
    
    at_least_one_significant = False
    for col in X.columns:
        if col == 'const':
            continue
        if model.pvalues[col] < 0.1:  # Assuming significant level at 0.1
            at_least_one_significant = True
            print(f"{col}: {round(model.params[col], 4)} (p-value: {round(model.pvalues[col], 4)})")
    
    if not at_least_one_significant:
        print("(no significant coefficients found)")
    print()
# Out:
# Total rows 452
# Model for next_star_count_end
# R-squared: 0.2129
# Adjusted R-squared: 0.1783
# Significant Coefficients:
# code_comment_deprecated_ratio: 6359.9076 (p-value: 0.0007)
# code_comment_explanation_ratio: 14127.8709 (p-value: 0.0)
# code_comment_future work_ratio: 7050.3998 (p-value: 0.0002)
# issue_comment_bug report_count_growth_rate: -3386.6348 (p-value: 0.092)
# issue_comment_bug report_ratio: 4696.279 (p-value: 0.0187)
# issue_comment_conclusion_ratio: 3924.7871 (p-value: 0.0423)
# issue_comment_discussion_ratio: 7750.438 (p-value: 0.0001)
# issue_comment_question_ratio: 11420.0423 (p-value: 0.0)
# positivity_ratio: 3502.4377 (p-value: 0.0652)
#
# Model for next_star_count_start
# R-squared: 0.208
# Adjusted R-squared: 0.1731
# Significant Coefficients:
# code_comment_deprecated_ratio: 6165.1463 (p-value: 0.0008)
# code_comment_explanation_ratio: 13620.1788 (p-value: 0.0)
# code_comment_future work_ratio: 6676.1897 (p-value: 0.0003)
# issue_comment_bug report_count_growth_rate: -3336.2853 (p-value: 0.0893)
# issue_comment_bug report_ratio: 4441.4805 (p-value: 0.0228)
# issue_comment_conclusion_ratio: 3827.0528 (p-value: 0.0427)
# issue_comment_discussion_ratio: 7419.9319 (p-value: 0.0002)
# issue_comment_question_ratio: 11035.4617 (p-value: 0.0)
# positivity_ratio: 3477.3135 (p-value: 0.061)
#
# Model for next_code_comment_count_growth_rate
# R-squared: 0.1491
# Adjusted R-squared: 0.1117
# Significant Coefficients:
# code_comment_explanation_count_growth_rate: -0.5189 (p-value: 0.0)
#
# Model for next_code_comment_deprecated_count_growth_rate
# R-squared: 0.1018
# Adjusted R-squared: 0.0623
# Significant Coefficients:
# code_comment_deprecated_count_growth_rate: -0.1627 (p-value: 0.0)
# code_comment_future work_ratio: -0.1082 (p-value: 0.0006)
# issue_comment_conclusion_count_growth_rate: -0.0662 (p-value: 0.0421)
#
# Model for next_code_comment_explanation_count_growth_rate
# R-squared: 0.1693
# Adjusted R-squared: 0.1328
# Significant Coefficients:
# code_comment_explanation_count_growth_rate: -0.5603 (p-value: 0.0)
#
# Model for next_code_comment_future work_count_growth_rate
# R-squared: 0.0739
# Adjusted R-squared: 0.0331
# Significant Coefficients:
# code_comment_deprecated_count_growth_rate: -0.0778 (p-value: 0.0963)
# code_comment_future work_count_growth_rate: -0.1806 (p-value: 0.0002)
# issue_comment_bug report_ratio: -0.0884 (p-value: 0.0567)
#
# Model for next_issue_comment_bug report_count_growth_rate
# R-squared: 0.1568
# Adjusted R-squared: 0.1197
# Significant Coefficients:
# code_comment_future work_ratio: 0.0363 (p-value: 0.0342)
# issue_comment_bug report_count_growth_rate: -0.1223 (p-value: 0.0)
#
# Model for next_issue_comment_conclusion_count_growth_rate
# R-squared: 0.1969
# Adjusted R-squared: 0.1616
# Significant Coefficients:
# code_comment_future work_count_growth_rate: -0.048 (p-value: 0.0464)
# issue_comment_conclusion_count_growth_rate: -0.183 (p-value: 0.0)
# issue_comment_conclusion_ratio: -0.0409 (p-value: 0.067)
# issue_comment_feature request_count_growth_rate: 0.0457 (p-value: 0.0468)
# issue_comment_question_count_growth_rate: 0.0733 (p-value: 0.0028)
#
# Model for next_issue_comment_count_growth_rate
# R-squared: 0.1077
# Adjusted R-squared: 0.0684
# Significant Coefficients:
# issue_comment_bug report_ratio: -0.054 (p-value: 0.0803)
# issue_comment_question_count_growth_rate: -0.13 (p-value: 0.0001)
# issue_comment_solution_count_growth_rate: -0.0916 (p-value: 0.0029)
# issue_comment_solution_ratio: 0.065 (p-value: 0.028)
#
# Model for next_issue_comment_discussion_count_growth_rate
# R-squared: 0.1936
# Adjusted R-squared: 0.1581
# Significant Coefficients:
# issue_comment_conclusion_ratio: 0.0564 (p-value: 0.0355)
# issue_comment_discussion_count_growth_rate: -0.1855 (p-value: 0.0)
# issue_comment_question_ratio: 0.0537 (p-value: 0.0702)
# issue_comment_solution_count_growth_rate: -0.1148 (p-value: 0.0)
#
# Model for next_issue_comment_feature request_count_growth_rate
# R-squared: 0.1323
# Adjusted R-squared: 0.0942
# Significant Coefficients:
# issue_comment_conclusion_count_growth_rate: 0.039 (p-value: 0.0778)
# issue_comment_feature request_count_growth_rate: -0.1564 (p-value: 0.0)
# issue_comment_question_ratio: 0.0423 (p-value: 0.0811)
#
# Model for next_issue_comment_question_count_growth_rate
# R-squared: 0.1959
# Adjusted R-squared: 0.1606
# Significant Coefficients:
# issue_comment_bug report_ratio: 0.0539 (p-value: 0.0797)
# issue_comment_question_count_growth_rate: -0.2465 (p-value: 0.0)
# issue_comment_solution_count_growth_rate: -0.0811 (p-value: 0.0081)
# issue_comment_solution_ratio: 0.0612 (p-value: 0.0376)
#
# Model for next_issue_comment_solution_count_growth_rate
# R-squared: 0.208
# Adjusted R-squared: 0.1732
# Significant Coefficients:
# issue_comment_bug report_count_growth_rate: -0.0399 (p-value: 0.0605)
# issue_comment_conclusion_count_growth_rate: 0.065 (p-value: 0.0017)
# issue_comment_question_count_growth_rate: 0.0677 (p-value: 0.0026)
# issue_comment_solution_count_growth_rate: -0.1752 (p-value: 0.0)
#
# Model for next_star_growth_rate
# R-squared: 0.0379
# Adjusted R-squared: -0.0044
# Significant Coefficients:
# code_comment_future work_ratio: 0.0121 (p-value: 0.0382)
# issue_comment_question_ratio: -0.0153 (p-value: 0.0204)
#
# Model for next_code_comment_deprecated_ratio
# R-squared: 0.0249
# Adjusted R-squared: -0.018
# Significant Coefficients:
# (no significant coefficients found)
#
# Model for next_code_comment_explanation_ratio
# R-squared: 0.3081
# Adjusted R-squared: 0.2777
# Significant Coefficients:
# code_comment_deprecated_ratio: 0.0576 (p-value: 0.0007)
# code_comment_explanation_ratio: 0.1476 (p-value: 0.0)
# code_comment_future work_ratio: 0.0382 (p-value: 0.0254)
# issue_comment_conclusion_ratio: -0.0391 (p-value: 0.0256)
# issue_comment_question_count_growth_rate: -0.0323 (p-value: 0.0923)
# issue_comment_question_ratio: -0.0641 (p-value: 0.001)
# issue_comment_solution_ratio: -0.0641 (p-value: 0.0002)
#
# Model for next_code_comment_future work_ratio
# R-squared: 0.0551
# Adjusted R-squared: 0.0135
# Significant Coefficients:
# code_comment_explanation_ratio: 0.0141 (p-value: 0.0358)
# code_comment_future work_ratio: 0.0133 (p-value: 0.0293)
# issue_comment_bug report_count_growth_rate: -0.0169 (p-value: 0.0097)
# issue_comment_bug report_ratio: 0.0144 (p-value: 0.0261)
# positivity_ratio: -0.0103 (p-value: 0.0937)
#
# Model for next_issue_comment_bug report_ratio
# R-squared: 0.1234
# Adjusted R-squared: 0.0848
# Significant Coefficients:
# issue_comment_conclusion_ratio: 0.004 (p-value: 0.0321)
# issue_comment_discussion_ratio: 0.0063 (p-value: 0.0011)
# issue_comment_question_ratio: 0.0065 (p-value: 0.0015)
#
# Model for next_issue_comment_conclusion_ratio
# R-squared: 0.1291
# Adjusted R-squared: 0.0908
# Significant Coefficients:
# code_comment_explanation_count_growth_rate: -0.0079 (p-value: 0.0548)
# issue_comment_discussion_ratio: 0.0089 (p-value: 0.0217)
# issue_comment_feature request_ratio: 0.0108 (p-value: 0.0033)
# issue_comment_question_ratio: 0.0221 (p-value: 0.0)
#
# Model for next_issue_comment_discussion_ratio
# R-squared: 0.2125
# Adjusted R-squared: 0.1779
# Significant Coefficients:
# issue_comment_conclusion_ratio: 0.0347 (p-value: 0.0)
# issue_comment_discussion_ratio: 0.0296 (p-value: 0.0002)
# issue_comment_question_ratio: 0.0401 (p-value: 0.0)
# issue_comment_solution_ratio: 0.0169 (p-value: 0.0224)
#
# Model for next_issue_comment_feature request_ratio
# R-squared: 0.1203
# Adjusted R-squared: 0.0816
# Significant Coefficients:
# code_comment_explanation_count_growth_rate: -0.0157 (p-value: 0.0621)
# issue_comment_feature request_ratio: 0.0243 (p-value: 0.0013)
# issue_comment_question_ratio: 0.04 (p-value: 0.0)
# positivity_ratio: -0.0133 (p-value: 0.0773)
#
# Model for next_issue_comment_question_ratio
# R-squared: 0.4682
# Adjusted R-squared: 0.4448
# Significant Coefficients:
# issue_comment_bug report_ratio: 0.0323 (p-value: 0.0058)
# issue_comment_conclusion_ratio: 0.032 (p-value: 0.0048)
# issue_comment_discussion_ratio: 0.0562 (p-value: 0.0)
# issue_comment_feature request_ratio: 0.0671 (p-value: 0.0)
# issue_comment_question_ratio: 0.1237 (p-value: 0.0)
# issue_comment_solution_ratio: 0.0866 (p-value: 0.0)
#
# Model for next_issue_comment_solution_ratio
# R-squared: 0.0742
# Adjusted R-squared: 0.0334
# Significant Coefficients:
# code_comment_explanation_ratio: -0.011 (p-value: 0.0758)
# issue_comment_bug report_ratio: 0.0107 (p-value: 0.0741)
# issue_comment_discussion_ratio: 0.0172 (p-value: 0.0045)
#
# Model for next_positivity_ratio
# R-squared: 0.0372
# Adjusted R-squared: -0.0051
# Significant Coefficients:
# issue_comment_conclusion_ratio: 0.019 (p-value: 0.0059)
#
# Model for star_growth_rate
# R-squared: 0.0312
# Adjusted R-squared: -0.0114
# Significant Coefficients:
# issue_comment_question_ratio: -0.0213 (p-value: 0.048)

# %%
comments = pd.read_csv('github_comments_with_future_stars.csv')
data = comments

# Function to run regression analysis
import statsmodels.api as sm
def run_regression_analysis(X, y):
    results = {}
    # Add constant to the model for the intercept
    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()

    # Store results
    results = model.summary()
    return results

for interval in [3]: # could be 1, 3, 6, 12
    data_testing = data.dropna(subset=[f'future_stars_{interval}_month'])
    data_testing = data_testing.dropna(subset=[f'future_stars_{interval}_month_growth_rate'])
    data_testing = data_testing[~data_testing[f'future_stars_{interval}_month_growth_rate'].isin([np.nan, np.inf, -np.inf])] # div by zero
    X = pd.get_dummies(data_testing[['sentiment_class', 'purpose']], drop_first=False).astype(int)
    X = X.drop(columns=['sentiment_class_NEGATIVE', 'purpose_explanation'])
    y = data_testing[f'future_stars_{interval}_month_growth_rate']
    y = np.log1p(y)

    print(run_regression_analysis(X,y))
# Out:
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     future_stars_3_month_growth_rate   R-squared:                       0.066
# Model:                                          OLS   Adj. R-squared:                  0.066
# Method:                               Least Squares   F-statistic:                     189.6
# Date:                              Thu, 11 Apr 2024   Prob (F-statistic):               0.00
# Time:                                      14:38:31   Log-Likelihood:                -15186.
# No. Observations:                             24155   AIC:                         3.039e+04
# Df Residuals:                                 24145   BIC:                         3.047e+04
# Df Model:                                         9
# Covariance Type:                          nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.4570      0.004    109.398      0.000       0.449       0.465
# sentiment_class_POSITIVE    -0.0123      0.008     -1.618      0.106      -0.027       0.003
# purpose_bug report          -0.2465      0.028     -8.878      0.000      -0.301      -0.192
# purpose_conclusion          -0.2500      0.020    -12.672      0.000      -0.289      -0.211
# purpose_deprecated          -0.1056      0.018     -5.712      0.000      -0.142      -0.069
# purpose_discussion          -0.2561      0.011    -22.666      0.000      -0.278      -0.234
# purpose_feature request     -0.2423      0.016    -15.048      0.000      -0.274      -0.211
# purpose_future work         -0.0074      0.014     -0.541      0.589      -0.034       0.019
# purpose_question            -0.2558      0.008    -33.408      0.000      -0.271      -0.241
# purpose_solution            -0.2249      0.018    -12.794      0.000      -0.259      -0.190
# ==============================================================================
# Omnibus:                    19938.916   Durbin-Watson:                   1.289
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           526475.949
# Skew:                           3.924   Prob(JB):                         0.00
# Kurtosis:                      24.483   Cond. No.                         9.99
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
